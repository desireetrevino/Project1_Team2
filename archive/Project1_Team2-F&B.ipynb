# %% [markdown]
# # F&B Data Analysis

# %%
# Dependencies:
import matplotlib.pyplot as plt
import pandas as pd
import requests
import datetime

# Import Yahoo Finance library to get Stock Market Data
import yfinance as yf

# %%
# Get stocks from library
fbstocks = yf.Tickers("bmboy bud ko gis adm ftxg pbj")
period = "5y"
fbstocks_hist = fbstocks.history(period=period)["Close"]
# Could also use: fbstocks_hist = fbstocks.history(start="2018-08-07", end="2023-08-07")
fbstocks_hist
# Out:
# [*********************100%***********************]  7 of 7 completed
#                   ADM      BMBOY        BUD       FTXG        GIS         KO  \
# Date
# 2018-08-13  43.048950   7.748396  89.300583  18.359364  38.439743  39.186245
# 2018-08-14  43.590115   7.748396  90.514114  18.359364  38.718723  39.237549
# 2018-08-15  43.445126   7.748396  91.134758  18.359364  39.082245  39.400009
# 2018-08-16  44.069042   7.748396  91.218132  18.359364  39.395035  39.519711
# 2018-08-17  44.420532   7.748396  92.505768  18.464216  39.910717  39.844620
# ...               ...        ...        ...        ...        ...        ...
# 2023-08-07  87.209999  20.299999  56.439999  26.570000  73.459999  61.189999
# 2023-08-08  86.440002  20.299999  56.320000  26.208000  71.360001  60.919998
# 2023-08-09  85.849998  20.299999  56.500000  26.219999  72.160004  61.060001
# 2023-08-10  85.900002  20.299999  56.840000  26.139999  72.379997  60.919998
# ...

# %%
# Date vs Stock Value for each Stock:
adm = fbstocks_hist["ADM"]
bmboy = fbstocks_hist["BMBOY"]
bud = fbstocks_hist["BUD"]
ftxg = fbstocks_hist["FTXG"]
gis = fbstocks_hist["GIS"]
ko = fbstocks_hist["KO"]
pbj = fbstocks_hist["PBJ"]

plt.figure(figsize=(20, 10))
adm.plot(linewidth=1)
bmboy.plot(linewidth=1)
bud.plot(linewidth=1)
ftxg.plot(linewidth=1)
gis.plot(linewidth=1)
ko.plot(linewidth=1)
pbj.plot(linewidth=1)


plt.legend(fontsize=10)
plt.axvline(datetime.datetime(2020, 1, 1), color='red', linewidth=1, linestyle='--')
plt.axvline(datetime.datetime(2021, 12, 1), color='red', linewidth=1, linestyle='--')
plt.show()

# %% [markdown]
# # Percentage Change

# %%
# Calculate percentage change for ETFs: FTXG and PBJ
# ((mar31 - jan1) / jan1)*100
ftxg_3m =
ftxg_6m =
ftxg_1y =
ftxg_2y =
ftxg_tdy =

# %%
fbstocks_hist[pd.to_datetime('2020-01-01')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('2020-01-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
# ...

# %%
fbstocks_hist.index
# Out:
# DatetimeIndex(['2018-08-13', '2018-08-14', '2018-08-15', '2018-08-16',
#                '2018-08-17', '2018-08-20', '2018-08-21', '2018-08-22',
#                '2018-08-23', '2018-08-24',
#                ...
#                '2023-07-31', '2023-08-01', '2023-08-02', '2023-08-03',
#                '2023-08-04', '2023-08-07', '2023-08-08', '2023-08-09',
#                '2023-08-10', '2023-08-11'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)
